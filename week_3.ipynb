# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url='cells_geo.csv'
df=pd.read_csv(url, delimiter = ';')
df.dtypes
df.head()
df.columns=['ID', 'CITY', 'STATUS', 'LOCALISATION', 'DECOUP_ZONE','ZONE_NAME', 'LONGITUDE', 'LATITUDE', 'REGION', 'AREA', 'CELL_ID', 'SITE_ID']

df
# Out:
#         ID      CITY      STATUS  ...          AREA     CELL_ID     SITE_ID
# 0        0    ADJAME  In Service  ...           NaN  fbb2e75af3  0bb492ef17
# 1        1    ADJAME  In Service  ...           NaN  1502501d78  0bb492ef17
# 2        2    ADJAME  In Service  ...           NaN  0c2e182a0c  0bb492ef17
# 3        3   ASSINIE  In Service  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4        4   ASSINIE  In Service  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...    ...       ...         ...  ...           ...         ...         ...
# 3969  3969  ZUENOULA  In Service  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  3970  ZUENOULA  In Service  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  3971  ZUENOULA  In Service  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  3972  ZUENOULA  In Service  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  3973  ZUENOULA  In Service  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [3974 rows x 12 columns]

# %%
df=df.drop_duplicates(keep='last')

df=df.dropna()
df
# Out:
#         ID      CITY      STATUS  ...           AREA     CELL_ID     SITE_ID
# 23      23     ABOBO  In Service  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24      24     ABOBO  In Service  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25      25     ABOBO  In Service  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26      26     ABOBO  In Service  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27      27     ABOBO  In Service  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...    ...       ...         ...  ...            ...         ...         ...
# 3969  3969  ZUENOULA  In Service  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  3970  ZUENOULA  In Service  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  3971  ZUENOULA  In Service  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  3972  ZUENOULA  In Service  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  3973  ZUENOULA  In Service  ...   CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [3880 rows x 12 columns]

# %%
df1=pd.read_csv('Telcom_dataset.csv')

df1.columns=['PRODUCT','BILLING_PRICE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT', 'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID']
df1
# Out:
#      PRODUCT  BILLING_PRICE  ...     CELL_ID     SITE_ID
# 0      Voice              0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms              0  ...  /+cKZKIp41  /+cKZKIp41
# 2        sms             25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice             56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice             14  ...  051KhYDCpv  051KhYDCpv
# ...      ...            ...  ...         ...         ...
# 4996     sms            100  ...  0c2371d9bc  1e751d08a4
# 4997   Voice              1  ...  5fb791cf56  65efe2bc62
# 4998   Voice              0  ...  7773627c12  9ef9616350
# 4999   Voice              0  ...  3f4af49d6c  969b8d0e39
# 5000   Voice              7  ...  6f4d9b77a5  ebfc58af70
#
# [5001 rows x 10 columns]

# %%
df1['DATETIME'] =  pd.to_datetime(df1['DATETIME'], format='%H:%M:%S.%f', infer_datetime_format=True)

df1['DATETIME']
# Out:
# 0      2012-05-06 23:04:37
# 1      2012-05-06 23:05:25
# 2      2012-05-06 23:05:41
# 3      2012-05-06 23:05:42
# 4      2012-05-06 23:06:29
#                ...
# 4996   2012-05-07 00:01:54
# 4997   2012-05-07 00:01:54
# 4998   2012-05-07 00:01:54
# 4999   2012-05-07 00:01:54
# 5000   2012-05-07 00:01:54
# Name: DATETIME, Length: 5001, dtype: datetime64[ns]

# %%
df2=pd.read_csv('Telcom_dataset2.csv')
df2.dtypes
df2.columns=['PRODUCT','BILLING_PRICE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT', 'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID']
df2
# Out:
#      PRODUCT  BILLING_PRICE DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        sms              0  02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1      Voice              0  03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2        sms              0  04:06.0  ...     19e2e      #NAME?      #NAME?
# 3      Voice             37  04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4        sms             25  04:58.0  ...     19e2e      #NAME?      #NAME?
# ...      ...            ...      ...  ...       ...         ...         ...
# 4996     sms              0  01:53.0  ...     19e2e  896459aace  b7d00e59e4
# 4997     sms             25  01:53.0  ...     19e2e  7e90b35166  211015b14d
# 4998     sms              0  01:53.0  ...     19e2e  fe70e431df  c7ea989264
# 4999    data              0  01:53.0  ...     OTHER  ffa6759bb2         NaN
# 5000   Voice              0  01:53.0  ...     19e2e  8630058aca  b47a998a3e
#
# [5001 rows x 10 columns]

# %%
df2['DATETIME'] =  pd.to_datetime('00:' + df2['DATETIME']) 

df2['DATETIME']
# Out:
# 0      2020-03-29 00:02:06
# 1      2020-03-29 00:03:44
# 2      2020-03-29 00:04:06
# 3      2020-03-29 00:04:48
# 4      2020-03-29 00:04:58
#                ...
# 4996   2020-03-29 00:01:53
# 4997   2020-03-29 00:01:53
# 4998   2020-03-29 00:01:53
# 4999   2020-03-29 00:01:53
# 5000   2020-03-29 00:01:53
# Name: DATETIME, Length: 5001, dtype: datetime64[ns]

# %%
df3=pd.read_csv('Telcom_dataset3.csv')
df3.dtypes
df3.head()
df3.columns=['PRODUCT','BILLING_PRICE', 'DATETIME', 'CELL_ON_SITE', 'DW_A_NUMBER_INT', 'DW_B_NUMBER_INT', 'COUNTRY_A', 'COUNTRY_B', 'CELL_ID', 'SITE_ID']
df3
# Out:
#      PRODUCT  BILLING_PRICE  ...     CELL_ID     SITE_ID
# 0      Voice             61  ...  +38u2u/rfx  +38u2u/rfx
# 1        sms              0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice             10  ...  +ZaaZozy/+  +ZaaZozy/+
# 3        sms              0  ...  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice             22  ...  /eeMklgyJA  /eeMklgyJA
# ...      ...            ...  ...         ...         ...
# 4996   Voice              0  ...  2aa04dcab7  f7d63a29e5
# 4997   Voice             62  ...  7f1f2f889f  b4ddb9e93c
# 4998   Voice             32  ...  a4731e780e  d68260ef50
# 4999   Voice             30  ...  98ed726da2  b4130b54ab
# 5000   Voice             60  ...  1c11a2fcbb  6d70dae094
#
# [5001 rows x 10 columns]

# %%
df3['DATETIME'] =  pd.to_datetime(df3['DATETIME'], format='%d%b%Y:%H:%M:%S.%f', infer_datetime_format=True)

df3['DATETIME']
# Out:
# 0      2012-05-08 23:01:28
# 1      2012-05-08 23:01:31
# 2      2012-05-08 23:02:59
# 3      2012-05-08 23:03:04
# 4      2012-05-08 23:03:16
#                ...
# 4996   2012-05-09 00:01:43
# 4997   2012-05-09 00:01:43
# 4998   2012-05-09 00:01:43
# 4999   2012-05-09 00:01:43
# 5000   2012-05-09 00:01:43
# Name: DATETIME, Length: 5001, dtype: datetime64[ns]

# %%
new_df=pd.concat([df1,df2,df3], axis=0)
new_df
# Out:
#      PRODUCT  BILLING_PRICE  ...     CELL_ID     SITE_ID
# 0      Voice              0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms              0  ...  /+cKZKIp41  /+cKZKIp41
# 2        sms             25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice             56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice             14  ...  051KhYDCpv  051KhYDCpv
# ...      ...            ...  ...         ...         ...
# 4996   Voice              0  ...  2aa04dcab7  f7d63a29e5
# 4997   Voice             62  ...  7f1f2f889f  b4ddb9e93c
# 4998   Voice             32  ...  a4731e780e  d68260ef50
# 4999   Voice             30  ...  98ed726da2  b4130b54ab
# 5000   Voice             60  ...  1c11a2fcbb  6d70dae094
#
# [15003 rows x 10 columns]

# %%
new_df9=new_df9.dropna()
new_df9
# Out:
#      PRODUCT  BILLING_PRICE            DATETIME  ...     CELL_ID     SITE_ID Hour
# 0      Voice              0 2012-05-06 23:04:37  ...  /TJNe+Mmtu  /TJNe+Mmtu   23
# 1        sms              0 2012-05-06 23:05:25  ...  /+cKZKIp41  /+cKZKIp41   23
# 2        sms             25 2012-05-06 23:05:41  ...  /u0FSD+ahi  /u0FSD+ahi   23
# 3      Voice             56 2012-05-06 23:05:42  ...  +cNeJzsTp3  +cNeJzsTp3   23
# 4      Voice             14 2012-05-06 23:06:29  ...  051KhYDCpv  051KhYDCpv   23
# ...      ...            ...                 ...  ...         ...         ...  ...
# 4996   Voice              0 2012-05-09 00:01:43  ...  2aa04dcab7  f7d63a29e5    0
# 4997   Voice             62 2012-05-09 00:01:43  ...  7f1f2f889f  b4ddb9e93c    0
# 4998   Voice             32 2012-05-09 00:01:43  ...  a4731e780e  d68260ef50    0
# 4999   Voice             30 2012-05-09 00:01:43  ...  98ed726da2  b4130b54ab    0
# ...

# %%
#changing the date format from object to datetime datatype

merged=new_df9.merge(df, how ='inner', on='SITE_ID')
merged
# Out:
#       PRODUCT  BILLING_PRICE  ...           AREA   CELL_ID_y
# 0         sms              0  ...   CENTRE NORTH  24ccdda3d5
# 1         sms              0  ...   CENTRE NORTH  ebfc58af70
# 2         sms              0  ...   CENTRE NORTH  ba8ce6e4ef
# 3         sms              0  ...   CENTRE NORTH  c2545171dc
# 4         sms              0  ...   CENTRE NORTH  f15bd5483f
# ...       ...            ...  ...            ...         ...
# 49338   Voice             17  ...  ABIDJAN NORTH  c179f33d5e
# 49339   Voice             17  ...  ABIDJAN NORTH  0a3f751619
# 49340     sms              0  ...   CENTRE NORTH  0427a26d34
# 49341     sms              0  ...   CENTRE NORTH  7c72293cf2
# 49342     sms              0  ...   CENTRE NORTH  be18b5b981
#
# [49343 rows x 22 columns]

# %%
merged=merged.dropna()
merged.head()
# Out:
#   PRODUCT  BILLING_PRICE  ...          AREA   CELL_ID_y
# 0     sms              0  ...  CENTRE NORTH  24ccdda3d5
# 1     sms              0  ...  CENTRE NORTH  ebfc58af70
# 2     sms              0  ...  CENTRE NORTH  ba8ce6e4ef
# 3     sms              0  ...  CENTRE NORTH  c2545171dc
# 4     sms              0  ...  CENTRE NORTH  f15bd5483f
#
# [5 rows x 22 columns]

# %%
results=merged['BILLING_PRICE'].groupby(merged['CITY']).sum().sort_values(ascending=False).head(10)
results=results.to_frame()
results
# Out:
#               BILLING_PRICE
# CITY
# YOPOUGON             200456
# COCODY               184674
# ABOBO                119236
# KOUMASSI              71356
# TREICHVILLE           64537
# ADJAME                60617
# MARCORY               59876
# YAMOUSSOUKRO          45090
# SAN-PEDRO             44137
# PORT-BOUET            37368

# %%
Which ones were the most used city for the three days?
Which cities were the most used during business and home hours?
Most used city for the three days?
